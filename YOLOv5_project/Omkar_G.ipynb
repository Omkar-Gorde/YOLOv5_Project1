# %%
# !pip install awscli
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 38.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 43.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 16.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# ...

# %%
# !aws s3 cp s3://greenoxdataset/mainbottledataset.zip /content/
# Out:
# download: s3://greenoxdataset/mainbottledataset.zip to ./mainbottledataset.zip

# %%
# !aws configure set aws_access_key_id AKIA2QGLTCHMM65LJOGZ
# !aws configure set aws_secret_access_key UvGk6A2YIAz96o8Gnay/IXCXRbGHqBSRS2rs3/U7

# %%
import zipfile
import pandas as pd

# Specify the path to your ZIP file
zip_file_path = '/content/mainbottledataset.zip'

extraction_directory = '/content'

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_directory)

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15966, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 15966 (delta 43), reused 50 (delta 24), pack-reused 15880
# Receiving objects: 100% (15966/15966), 14.64 MiB | 21.48 MiB/s, done.
# Resolving deltas: 100% (10942/10942), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-216-gec690e4 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.2/78.2 GB disk)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/train/images
# Out:
# Streaming output truncated to the last 5000 lines.
# image 6976/11973 /content/train/images/PET_IMG_20200302_135913_riverdataset.jpg: 640x384 (no detections), 7.7ms
# image 6977/11973 /content/train/images/PET_IMG_20200302_140003_riverdataset.jpg: 640x384 (no detections), 7.7ms
# image 6978/11973 /content/train/images/PET_IMG_20200302_140008_riverdataset.jpg: 640x384 1 boat, 9.1ms
# image 6979/11973 /content/train/images/PET_IMG_20200302_140024_riverdataset.jpg: 640x384 2 boats, 7.7ms
# image 6980/11973 /content/train/images/PET_IMG_20200302_140030_riverdataset.jpg: 640x384 1 boat, 1 bird, 7.7ms
# image 6981/11973 /content/train/images/PET_IMG_20200302_140119_riverdataset.jpg: 640x384 1 boat, 7.7ms
# image 6982/11973 /content/train/images/PET_IMG_20200302_140154_riverdataset.jpg: 640x384 1 boat, 7.7ms
# image 6983/11973 /content/train/images/PET_IMG_20200302_140211_riverdataset.jpg: 640x384 1 boat, 7.7ms
# ...

# %%
# !python val.py --weights yolov5s.pt --data /content/valid --img 640 --half
# Out:
# Traceback (most recent call last):
#   File "/content/yolov5/val.py", line 410, in <module>
#     opt = parse_opt()
#   File "/content/yolov5/val.py", line 367, in parse_opt
#     opt.data = check_yaml(opt.data)  # check YAML
#   File "/content/yolov5/utils/general.py", line 442, in check_yaml
#     return check_file(file, suffix)
#   File "/content/yolov5/utils/general.py", line 469, in check_file
#     assert len(files) == 1, f"Multiple files match '{file}', specify exact path: {files}"  # assert unique
# AssertionError: Multiple files match '/content/valid', specify exact path: ['/content/valid', '/content/valid', '/content/valid']

# %%
# !python train.py --img 640 --batch 16 --epochs 20 --data /content/train --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/train, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# Traceback (most recent call last):
#   File "/content/yolov5/train.py", line 647, in <module>
#     main(opt)
#   File "/content/yolov5/train.py", line 511, in main
#     check_file(opt.data), check_yaml(opt.cfg), check_yaml(opt.hyp), str(opt.weights), str(opt.project)  # checks
# ...
